# %% [markdown]
# # EcoHome Energy Advisor - Agent Run & Evaluation
#
# In this notebook, you'll run the Energy Advisor agent with various real-world scenarios and see how it helps customers optimize their energy usage.
#
# ## Learning Objectives
# - Create the agent's instructions
# - Run the Energy Advisor with different types of questions
# - Evaluate response quality and accuracy
# - Measure tool usage effectiveness
# - Identify areas for improvement
# - Implement evaluation metrics
#
# ## Evaluation Criteria
# - **Accuracy**: Correct information and calculations
# - **Relevance**: Responses address the user's question
# - **Completeness**: Comprehensive answers with actionable advice
# - **Tool Usage**: Appropriate use of available tools
# - **Reasoning**: Clear explanation of recommendations

# %% [markdown]
# ## 1. Import and Initialize

# %%
from datetime import datetime
from agent import Agent

# %%
## TODO: Create the agent's instructions

ECOHOME_SYSTEM_PROMPT = """
You are EcoHome, an AI assistant that helps users save energy and reduce their carbon footprint at home. 

Your goal is to provide practical, actionable advice based on the user's specific home setup and energy usage patterns. 
"""

# %%
ecohome_agent = Agent(
    instructions=ECOHOME_SYSTEM_PROMPT,
)

# %%
response = ecohome_agent.invoke(
    question="When should I charge my electric car tomorrow to minimize cost and maximize solar power?",
    context="Location: San Francisco, CA"
)

# %%
print(response["messages"][-1].content)
# Out:
# To minimize costs and maximize solar power for charging your electric car tomorrow (October 7, 2023), here are the key insights:
#
# ### Electricity Pricing (Time of Use)
# - **Off-Peak Rates** (Lowest Cost):
#   - 12 AM - 5 AM: $0.118 to $0.136 per kWh
#   - 10 PM - 11 PM: $0.136 to $0.130 per kWh
#
# - **Peak Rates** (Highest Cost):
#   - 6 AM - 9 PM: $0.201 to $0.222 per kWh
#
# ### Solar Power Generation Forecast
# - **Best Solar Generation Hours**:
#   - **12 PM - 1 PM**: High solar irradiance (861.8 W/m²)
#   - **1 PM - 2 PM**: Moderate solar irradiance (496.6 W/m²)
#   - **2 PM - 3 PM**: Lower solar irradiance (681.1 W/m²)
#
# ### Recommendations
# 1. **Charge During Off-Peak Hours**:
#    - The best time to charge your electric car would be during the off-peak hours of **12 AM - 5 AM** to take advantage of the lowest rates.
#
# 2. **Consider Solar Generation**:
#    - If you have solar panels, consider charging your car during the peak solar generation hours of **12 PM - 2 PM**. This way, you can utilize the energy generated by your solar panels, which may reduce your reliance on grid electricity.
#
# ### Conclusion
# - **Optimal Charging Time**:
#   - **12 AM - 5 AM** for the lowest cost.
#   - **12 PM - 2 PM** if you have solar panels to maximize solar energy usage.
#
# By following these recommendations, you can effectively minimize your charging costs while maximizing the use of solar power.

# %%
print("TOOLS:")
for msg in response["messages"]:
    obj = msg.model_dump()
    if obj.get("tool_call_id"):
        print("-", msg.name)
# Out:
# TOOLS:
# - get_electricity_prices
# - get_weather_forecast

# %% [markdown]
# ## 2. Define Test Cases

# %%
# TODO: Define comprehensive test cases for the Energy Advisor
# Create 10 test cases covering different scenarios:
# - EV charging optimization
# - Thermostat settings
# - Appliance scheduling
# - Solar power maximization
# - Cost savings calculations

# %%
test_cases = [
    {
        "id": "ev_charging_1",
        "question": "When should I charge my electric car tomorrow to minimize cost and maximize solar power?",
        "expected_tools": ["get_weather_forecast", "get_electricity_prices"],
        "expected_response": "The response should contain time recommendation, cost analysis and solar consideration",
    },
    {
        "id": "thermostat_setting_1",
        "question": "What is the optimal thermostat setting for my home during a heatwave?",
        "expected_tools": ["get_weather_forecast", "get_energy_saving_tips"],
        "expected_response": "The response should include recommended temperature settings and energy-saving tips",
    },
    {
        "id": "appliance_scheduling_1",
        "question": "When should I run my dishwasher to save on energy costs?",
        "expected_tools": ["get_electricity_prices"],
        "expected_response": "The response should provide specific time slots for running the dishwasher",
    },
    {
        "id": "solar_power_maximization_1",
        "question": "How can I maximize my solar power usage this weekend?",
        "expected_tools": ["get_weather_forecast", "get_solar_power_tips"],
        "expected_response": "The response should include strategies for maximizing solar power usage",
    },
    {
        "id": "cost_savings_calculation_1",
        "question": "How much can I save by adjusting my thermostat by 2 degrees?",
        "expected_tools": ["calculate_energy_savings"],
        "expected_response": "The response should provide a detailed cost savings calculation",
    },
    {
        "id": "ev_charging_2",
        "question": "Is it cheaper to charge my EV at night or during the day?",
        "expected_tools": ["get_electricity_prices"],
        "expected_response": "The response should compare costs and provide a recommendation",
    },
    {
        "id": "thermostat_setting_2",
        "question": "What thermostat settings should I use in winter to save energy?",
        "expected_tools": ["get_energy_saving_tips"],
        "expected_response": "The response should include recommended temperature settings and energy-saving tips",
    },
    {
        "id": "appliance_scheduling_2",
        "question": "When is the best time to run my washing machine to save energy?",
        "expected_tools": ["get_electricity_prices"],
        "expected_response": "The response should provide specific time slots for running the washing machine",
    },
    {
        "id": "solar_power_maximization_2",
        "question": "What are the best practices for using solar power during cloudy days?",
        "expected_tools": ["get_solar_power_tips"],
        "expected_response": "The response should include strategies for maximizing solar power usage on cloudy days",
    },
    {
        "id": "cost_savings_calculation_2",
        "question": "How much can I save by using energy-efficient appliances?",
        "expected_tools": ["calculate_energy_savings"],
        "expected_response": "The response should provide a detailed cost savings calculation based on appliance efficiency",
    }
]

if len(test_cases) < 10:
    raise ValueError("You MUST have at least 10 test cases")

# %% [markdown]
# ## 3. Run Agent Tests

# %%
CONTEXT = "Location: San Francisco, CA"

# %%
# Run the agent tests
# For each test case, call the agent and collect the response
# Store results for evaluation

print("=== Running Agent Tests ===")
test_results = []

for i, test_case in enumerate(test_cases):
    print(f"\nTest {i+1}: {test_case['id']}")
    print(f"Question: {test_case['question']}")
    print("-" * 50)
    
    try:
        # Call the agent
        response = ecohome_agent.invoke(
            question=test_case['question'],
            context=CONTEXT
        )
        
        # Store the result
        result = {
            'test_id': test_case['id'],
            'question': test_case['question'],
            'response': response,
            'expected_tools': test_case['expected_tools'],
            'expected_response': test_case['expected_response'],
            'timestamp': datetime.now().isoformat()
        }
        test_results.append(result)
                
    except Exception as e:
        print(f"Error: {e}")
        result = {
            'test_id': test_case['id'],
            'question': test_case['question'],
            'response': f"Error: {str(e)}",
            'expected_tools': test_case['expected_tools'],
            'expected_response': test_case['expected_response'],
            'timestamp': datetime.now().isoformat(),
            'error': str(e)
        }
        test_results.append(result)

print(f"\nCompleted {len(test_results)} tests")
# Out:
# === Running Agent Tests ===
#
# Test 1: ev_charging_1
# Question: When should I charge my electric car tomorrow to minimize cost and maximize solar power?
# --------------------------------------------------
#
# Test 2: thermostat_setting_1
# Question: What is the optimal thermostat setting for my home during a heatwave?
# --------------------------------------------------
#
# Test 2: thermostat_setting_1
# Question: What is the optimal thermostat setting for my home during a heatwave?
# --------------------------------------------------
#
# Test 3: appliance_scheduling_1
# Question: When should I run my dishwasher to save on energy costs?
# --------------------------------------------------
#
# Test 3: appliance_scheduling_1
# Question: When should I run my dishwasher to save on energy costs?
# --------------------------------------------------
#
# Test 4: solar_power_maximization_1
# Question: How can I maximize my solar power usage this weekend?
# --------------------------------------------------
#
# Test 4: solar_power_maximization_1
# Question: How can I maximize my solar power usage this weekend?
# --------------------------------------------------
#
# Test 5: cost_savings_calculation_1
# Question: How much can I save by adjusting my thermostat by 2 degrees?
# --------------------------------------------------
#
# Test 5: cost_savings_calculation_1
# Question: How much can I save by adjusting my thermostat by 2 degrees?
# --------------------------------------------------
#
# Test 6: ev_charging_2
# Question: Is it cheaper to charge my EV at night or during the day?
# --------------------------------------------------
#
# Test 6: ev_charging_2
# Question: Is it cheaper to charge my EV at night or during the day?
# --------------------------------------------------
#
# Test 7: thermostat_setting_2
# Question: What thermostat settings should I use in winter to save energy?
# --------------------------------------------------
#
# Test 7: thermostat_setting_2
# Question: What thermostat settings should I use in winter to save energy?
# --------------------------------------------------
#
# Test 8: appliance_scheduling_2
# Question: When is the best time to run my washing machine to save energy?
# --------------------------------------------------
#
# Test 8: appliance_scheduling_2
# Question: When is the best time to run my washing machine to save energy?
# --------------------------------------------------
#
# Test 9: solar_power_maximization_2
# Question: What are the best practices for using solar power during cloudy days?
# --------------------------------------------------
#
# Test 9: solar_power_maximization_2
# Question: What are the best practices for using solar power during cloudy days?
# --------------------------------------------------
#
# Test 10: cost_savings_calculation_2
# Question: How much can I save by using energy-efficient appliances?
# --------------------------------------------------
#
# Test 10: cost_savings_calculation_2
# Question: How much can I save by using energy-efficient appliances?
# --------------------------------------------------
#
# Completed 10 tests
#
# Completed 10 tests

# %%
test_results
# Out:
# [{'test_id': 'ev_charging_1',
#   'question': 'When should I charge my electric car tomorrow to minimize cost and maximize solar power?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='64481c4f-bbb7-4c41-bfbf-fc255d89d907'),
#     HumanMessage(content='When should I charge my electric car tomorrow to minimize cost and maximize solar power?', additional_kwargs={}, response_metadata={}, id='a97c5bc8-ae8a-48c2-94a3-a8fef814a0b7'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 907, 'total_tokens': 968, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CsVwgwpR7kj3rwx82SgwaWcePFtL0', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019b6fe0-8cfd-7072-8861-3e65a5499a5c-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {'date': '2023-10-07'}, 'id': 'call_r6h3LSfDx60ywOAbFiksrLtg', 'type': 'tool_call'}, {'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_AVAPU1J1Dq9ppCyubmJMbERM', 'type': 'tool_call'}], usage_metadata={'input_tokens': 907, 'output_tokens': 61, 'total_tokens': 968, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"date": "2023-10-07", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.107, "period": "off-peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.138, "period": "off-peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.114, "period": "off-peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.12, "period": "off-peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.138, "period": "off-peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.135, "period": "off-peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.208, "period": "peak", "demand_charge": 0.086}, {"hour": 7, "rate": 0.193, "period": "peak", "demand_charge": 0.052}, {"hour": 8, "rate": 0.198, "period": "peak", "demand_charge": 0.064}, {"hour": 9, "rate": 0.18, "period": "peak", "demand_charge": 0.088}, {"hour": 10, "rate": 0.218, "period": "peak", "demand_charge": 0.099}, {"hour": 11, "rate": 0.211, "period": "peak", "demand_charge": 0.063}, {"hour": 12, "rate": 0.215, "period": "peak", "demand_charge": 0.073}, {"hour": 13, "rate": 0.22, "period": "peak", "demand_charge": 0.055}, {"hour": 14, "rate": 0.209, "period": "peak", "demand_charge": 0.09}, {"hour": 15, "rate": 0.186, "period": "peak", "demand_charge": 0.064}, {"hour": 16, "rate": 0.21, "period": "peak", "demand_charge": 0.09}, {"hour": 17, "rate": 0.217, "period": "peak", "demand_charge": 0.085}, {"hour": 18, "rate": 0.224, "period": "peak", "demand_charge": 0.054}, {"hour": 19, "rate": 0.217, "period": "peak", "demand_charge": 0.077}, {"hour": 20, "rate": 0.211, "period": "peak", "demand_charge": 0.056}, {"hour": 21, "rate": 0.213, "period": "peak", "demand_charge": 0.061}, {"hour": 22, "rate": 0.106, "period": "off-peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.146, "period": "off-peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='b6981c59-8949-4ea1-b65c-d7074eff7cac', tool_call_id='call_r6h3LSfDx60ywOAbFiksrLtg'),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 1, "current": {"temperature_c": 26.2, "condition": "sunny", "humidity": 30, "wind_speed": 4.6}, "hourly": [{"hour": 0, "temperature_c": 28.4, "condition": "sunny", "solar_irradiance": 715.2, "humidity": 56, "wind_speed": 11.1}, {"hour": 1, "temperature_c": 25.7, "condition": "partly_cloudy", "solar_irradiance": 44.8, "humidity": 72, "wind_speed": 13.7}, {"hour": 2, "temperature_c": 21.5, "condition": "sunny", "solar_irradiance": 160.8, "humidity": 37, "wind_speed": 2.1}, {"hour": 3, "temperature_c": 25.0, "condition": "sunny", "solar_irradiance": 773.4, "humidity": 53, "wind_speed": 6.7}, {"hour": 4, "temperature_c": 27.1, "condition": "partly_cloudy", "solar_irradiance": 817.2, "humidity": 80, "wind_speed": 9.6}, {"hour": 5, "temperature_c": 21.8, "condition": "sunny", "solar_irradiance": 479.9, "humidity": 51, "wind_speed": 5.0}, {"hour": 6, "temperature_c": 18.0, "condition": "cloudy", "solar_irradiance": 517.0, "humidity": 40, "wind_speed": 3.9}, {"hour": 7, "temperature_c": 23.5, "condition": "cloudy", "solar_irradiance": 894.2, "humidity": 77, "wind_speed": 3.0}, {"hour": 8, "temperature_c": 21.3, "condition": "cloudy", "solar_irradiance": 627.5, "humidity": 40, "wind_speed": 13.8}, {"hour": 9, "temperature_c": 29.2, "condition": "partly_cloudy", "solar_irradiance": 864.7, "humidity": 50, "wind_speed": 12.3}, {"hour": 10, "temperature_c": 17.3, "condition": "sunny", "solar_irradiance": 752.5, "humidity": 53, "wind_speed": 4.1}, {"hour": 11, "temperature_c": 27.7, "condition": "cloudy", "solar_irradiance": 682.5, "humidity": 75, "wind_speed": 14.6}, {"hour": 12, "temperature_c": 25.6, "condition": "sunny", "solar_irradiance": 285.1, "humidity": 50, "wind_speed": 9.6}, {"hour": 13, "temperature_c": 19.3, "condition": "sunny", "solar_irradiance": 989.0, "humidity": 55, "wind_speed": 4.8}, {"hour": 14, "temperature_c": 27.3, "condition": "partly_cloudy", "solar_irradiance": 896.0, "humidity": 38, "wind_speed": 0.5}, {"hour": 15, "temperature_c": 21.3, "condition": "cloudy", "solar_irradiance": 280.3, "humidity": 64, "wind_speed": 1.8}, {"hour": 16, "temperature_c": 22.7, "condition": "cloudy", "solar_irradiance": 452.4, "humidity": 71, "wind_speed": 13.9}, {"hour": 17, "temperature_c": 24.8, "condition": "cloudy", "solar_irradiance": 67.9, "humidity": 67, "wind_speed": 13.7}, {"hour": 18, "temperature_c": 26.7, "condition": "sunny", "solar_irradiance": 769.9, "humidity": 31, "wind_speed": 13.7}, {"hour": 19, "temperature_c": 16.8, "condition": "partly_cloudy", "solar_irradiance": 556.3, "humidity": 61, "wind_speed": 4.5}, {"hour": 20, "temperature_c": 17.4, "condition": "cloudy", "solar_irradiance": 680.5, "humidity": 42, "wind_speed": 5.3}, {"hour": 21, "temperature_c": 24.8, "condition": "cloudy", "solar_irradiance": 382.0, "humidity": 31, "wind_speed": 2.6}, {"hour": 22, "temperature_c": 28.5, "condition": "partly_cloudy", "solar_irradiance": 111.6, "humidity": 32, "wind_speed": 8.8}, {"hour": 23, "temperature_c": 15.1, "condition": "partly_cloudy", "solar_irradiance": 224.4, "humidity": 80, "wind_speed": 2.1}]}', name='get_weather_forecast', id='096c4f6e-773c-4d17-88a8-07c50e252176', tool_call_id='call_AVAPU1J1Dq9ppCyubmJMbERM'),
#     AIMessage(content='To minimize costs and maximize solar power when charging your electric car tomorrow (October 7, 2023), here are the key insights:\n\n### Electricity Pricing (Time of Use)\n- **Off-Peak Rates** (Lower cost):\n  - 12 AM - 6 AM: $0.107 to $0.208 per kWh\n  - 10 PM - 11 PM: $0.106 to $0.146 per kWh\n- **Peak Rates** (Higher cost):\n  - 6 AM - 10 PM: $0.180 to $0.224 per kWh\n\n### Solar Power Generation Forecast\n- **Best Solar Generation Hours**:\n  - **12 PM - 2 PM**: High solar irradiance, especially at 1 PM (989.0 W/m²).\n  - **9 AM - 11 AM**: Good solar generation, peaking at 9 AM (864.7 W/m²).\n  \n### Recommendations\n1. **Charge During Off-Peak Hours**:\n   - **Best Time**: Start charging after 10 PM tonight or early in the morning before 6 AM to take advantage of lower rates.\n   \n2. **Maximize Solar Power**:\n   - If you prefer to charge during the day, consider charging between **12 PM and 2 PM** when solar generation is at its peak. However, be aware that the rates during this time will be higher (around $0.215 to $0.22 per kWh).\n\n### Conclusion\n- **Ideal Charging Strategy**: Charge your electric car overnight (after 10 PM) to benefit from the lowest rates, or charge during the peak solar hours (12 PM - 2 PM) if you want to utilize solar energy, but expect to pay more for the electricity.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 373, 'prompt_tokens': 3005, 'total_tokens': 3378, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsVwi7472N2Q5BS3n49wgzzCLEtMA', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019b6fe0-9689-7810-a309-0c212456cd3d-0', usage_metadata={'input_tokens': 3005, 'output_tokens': 373, 'total_tokens': 3378, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_weather_forecast', 'get_electricity_prices'],
#   'expected_response': 'The response should contain time recommendation, cost analysis and solar consideration',
#   'timestamp': '2025-12-30T15:29:15.322697'},
#  {'test_id': 'thermostat_setting_1',
#   'question': 'What is the optimal thermostat setting for my home during a heatwave?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='70359a61-e8f4-4063-86b1-aff49c08f82d'),
#     HumanMessage(content='What is the optimal thermostat setting for my home during a heatwave?', additional_kwargs={}, response_metadata={}, id='203b34ba-fc4a-4e36-885a-16b0ea0d5226'),
#     AIMessage(content="During a heatwave, it's important to keep your home cool while also being energy-efficient. Here are some optimal thermostat settings and tips:\n\n1. **Set the Thermostat Higher**: Aim to set your thermostat to around 78°F (26°C) when you're at home. This helps to keep your home comfortable without overworking your air conditioning system.\n\n2. **Use Fans**: If you have ceiling fans, use them to help circulate cool air. You can set the thermostat a bit higher if you use fans, as they can make you feel cooler.\n\n3. **Avoid Extreme Temperature Changes**: Setting the thermostat too low (like 70°F or lower) can lead to excessive energy use and strain on your AC unit. \n\n4. **Utilize Programmable Thermostats**: If you have a programmable thermostat, set it to increase the temperature when you're not home and cool down before you return.\n\n5. **Close Blinds and Curtains**: Keep blinds and curtains closed during the hottest parts of the day to block out heat from the sun.\n\n6. **Consider Nighttime Cooling**: If temperatures drop at night, consider turning the thermostat up and using natural ventilation to cool your home.\n\nWould you like more specific tips based on your current energy usage or weather conditions?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 261, 'prompt_tokens': 905, 'total_tokens': 1166, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CsVwp1l48lVH00pkPq4gqhxpV3e4f', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019b6fe0-b23c-75e0-b4d9-c40e6baef91b-0', usage_metadata={'input_tokens': 905, 'output_tokens': 261, 'total_tokens': 1166, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_weather_forecast', 'get_energy_saving_tips'],
#   'expected_response': 'The response should include recommended temperature settings and energy-saving tips',
#   'timestamp': '2025-12-30T15:29:21.797077'},
#  {'test_id': 'appliance_scheduling_1',
#   'question': 'When should I run my dishwasher to save on energy costs?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='32a84aed-10aa-43e9-8c01-89c666a29a9c'),
#     HumanMessage(content='When should I run my dishwasher to save on energy costs?', additional_kwargs={}, response_metadata={}, id='f03d1207-3b4a-45fe-b1c2-4786fc749300'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 903, 'total_tokens': 916, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsVwwhFzBObcPJ6FlMIEwSdP31ejI', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019b6fe0-cb87-7542-b452-8bd6b360a967-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {}, 'id': 'call_0NJw1GdK27DqEe8pSHqK3Ktz', 'type': 'tool_call'}], usage_metadata={'input_tokens': 903, 'output_tokens': 13, 'total_tokens': 916, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"date": "2025-12-30", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.122, "period": "off-peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.121, "period": "off-peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.11, "period": "off-peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.115, "period": "off-peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.129, "period": "off-peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.115, "period": "off-peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.199, "period": "peak", "demand_charge": 0.086}, {"hour": 7, "rate": 0.216, "period": "peak", "demand_charge": 0.083}, {"hour": 8, "rate": 0.221, "period": "peak", "demand_charge": 0.062}, {"hour": 9, "rate": 0.223, "period": "peak", "demand_charge": 0.086}, {"hour": 10, "rate": 0.207, "period": "peak", "demand_charge": 0.073}, {"hour": 11, "rate": 0.195, "period": "peak", "demand_charge": 0.053}, {"hour": 12, "rate": 0.181, "period": "peak", "demand_charge": 0.08}, {"hour": 13, "rate": 0.224, "period": "peak", "demand_charge": 0.057}, {"hour": 14, "rate": 0.186, "period": "peak", "demand_charge": 0.061}, {"hour": 15, "rate": 0.221, "period": "peak", "demand_charge": 0.07}, {"hour": 16, "rate": 0.198, "period": "peak", "demand_charge": 0.059}, {"hour": 17, "rate": 0.186, "period": "peak", "demand_charge": 0.08}, {"hour": 18, "rate": 0.218, "period": "peak", "demand_charge": 0.088}, {"hour": 19, "rate": 0.197, "period": "peak", "demand_charge": 0.057}, {"hour": 20, "rate": 0.19, "period": "peak", "demand_charge": 0.066}, {"hour": 21, "rate": 0.213, "period": "peak", "demand_charge": 0.081}, {"hour": 22, "rate": 0.117, "period": "off-peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.134, "period": "off-peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='96875dfc-43d3-46fb-a8f9-ea4ec9f9a182', tool_call_id='call_0NJw1GdK27DqEe8pSHqK3Ktz'),
#     AIMessage(content='To save on energy costs when running your dishwasher, you should aim to operate it during off-peak hours when electricity rates are lower. Based on the current electricity pricing for San Francisco, here are the off-peak hours and their corresponding rates:\n\n- **12 AM - 6 AM**: Rates range from $0.11 to $0.129\n- **10 PM - 11 PM**: Rates are $0.117 and $0.134\n\nThe best time to run your dishwasher would be between **12 AM and 6 AM** or after **10 PM**. This way, you can take advantage of the lower rates and save on your energy costs.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 138, 'prompt_tokens': 1707, 'total_tokens': 1845, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CsVwxbfTiVEdbHm40aeUdyL65Zmsf', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019b6fe0-d0f9-7c60-8d7b-b51404afc923-0', usage_metadata={'input_tokens': 1707, 'output_tokens': 138, 'total_tokens': 1845, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_electricity_prices'],
#   'expected_response': 'The response should provide specific time slots for running the dishwasher',
#   'timestamp': '2025-12-30T15:29:26.243159'},
#  {'test_id': 'solar_power_maximization_1',
#   'question': 'How can I maximize my solar power usage this weekend?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='6b0d3fec-abdb-4822-9296-8f2f87df55f0'),
#     HumanMessage(content='How can I maximize my solar power usage this weekend?', additional_kwargs={}, response_metadata={}, id='58922504-4b63-4b50-a046-e7cb7edba8ed'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 902, 'total_tokens': 925, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CsVx0R7b9032d2bEqEsyif9acf9H1', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019b6fe0-dce5-7663-bee3-55803881e9ce-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 3}, 'id': 'call_zFzqJVB4PtSIBYUBxvfJUzh1', 'type': 'tool_call'}], usage_metadata={'input_tokens': 902, 'output_tokens': 23, 'total_tokens': 925, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 3, "current": {"temperature_c": 24.6, "condition": "cloudy", "humidity": 52, "wind_speed": 4.2}, "hourly": [{"hour": 0, "temperature_c": 16.3, "condition": "partly_cloudy", "solar_irradiance": 947.7, "humidity": 78, "wind_speed": 9.1}, {"hour": 1, "temperature_c": 21.1, "condition": "cloudy", "solar_irradiance": 343.5, "humidity": 54, "wind_speed": 5.0}, {"hour": 2, "temperature_c": 20.2, "condition": "cloudy", "solar_irradiance": 711.0, "humidity": 56, "wind_speed": 2.8}, {"hour": 3, "temperature_c": 24.2, "condition": "cloudy", "solar_irradiance": 181.4, "humidity": 73, "wind_speed": 9.0}, {"hour": 4, "temperature_c": 17.6, "condition": "sunny", "solar_irradiance": 347.5, "humidity": 48, "wind_speed": 0.7}, {"hour": 5, "temperature_c": 26.7, "condition": "sunny", "solar_irradiance": 910.4, "humidity": 65, "wind_speed": 5.6}, {"hour": 6, "temperature_c": 25.7, "condition": "cloudy", "solar_irradiance": 351.6, "humidity": 34, "wind_speed": 1.5}, {"hour": 7, "temperature_c": 20.9, "condition": "cloudy", "solar_irradiance": 360.2, "humidity": 53, "wind_speed": 2.8}, {"hour": 8, "temperature_c": 21.8, "condition": "cloudy", "solar_irradiance": 197.5, "humidity": 32, "wind_speed": 4.1}, {"hour": 9, "temperature_c": 22.9, "condition": "partly_cloudy", "solar_irradiance": 391.1, "humidity": 34, "wind_speed": 14.9}, {"hour": 10, "temperature_c": 23.5, "condition": "sunny", "solar_irradiance": 437.6, "humidity": 65, "wind_speed": 7.3}, {"hour": 11, "temperature_c": 17.8, "condition": "cloudy", "solar_irradiance": 66.1, "humidity": 61, "wind_speed": 7.6}, {"hour": 12, "temperature_c": 29.6, "condition": "partly_cloudy", "solar_irradiance": 566.4, "humidity": 55, "wind_speed": 0.2}, {"hour": 13, "temperature_c": 27.6, "condition": "partly_cloudy", "solar_irradiance": 108.6, "humidity": 80, "wind_speed": 12.9}, {"hour": 14, "temperature_c": 27.4, "condition": "partly_cloudy", "solar_irradiance": 250.3, "humidity": 48, "wind_speed": 2.6}, {"hour": 15, "temperature_c": 16.4, "condition": "sunny", "solar_irradiance": 72.6, "humidity": 68, "wind_speed": 1.8}, {"hour": 16, "temperature_c": 15.4, "condition": "cloudy", "solar_irradiance": 685.7, "humidity": 74, "wind_speed": 1.9}, {"hour": 17, "temperature_c": 21.9, "condition": "cloudy", "solar_irradiance": 203.9, "humidity": 75, "wind_speed": 11.7}, {"hour": 18, "temperature_c": 21.3, "condition": "cloudy", "solar_irradiance": 774.4, "humidity": 35, "wind_speed": 11.8}, {"hour": 19, "temperature_c": 15.6, "condition": "sunny", "solar_irradiance": 219.0, "humidity": 60, "wind_speed": 8.9}, {"hour": 20, "temperature_c": 27.8, "condition": "sunny", "solar_irradiance": 608.6, "humidity": 57, "wind_speed": 0.3}, {"hour": 21, "temperature_c": 25.3, "condition": "sunny", "solar_irradiance": 910.4, "humidity": 40, "wind_speed": 1.2}, {"hour": 22, "temperature_c": 15.1, "condition": "sunny", "solar_irradiance": 825.9, "humidity": 37, "wind_speed": 14.9}, {"hour": 23, "temperature_c": 24.5, "condition": "partly_cloudy", "solar_irradiance": 52.2, "humidity": 55, "wind_speed": 9.2}]}', name='get_weather_forecast', id='4f910e24-d289-4c59-be07-1fc037650314', tool_call_id='call_zFzqJVB4PtSIBYUBxvfJUzh1'),
#     AIMessage(content="To maximize your solar power usage this weekend in San Francisco, here are some actionable tips based on the weather forecast:\n\n### Weather Overview\n- **Saturday**: Expect partly cloudy conditions with peak solar irradiance around midday.\n- **Sunday**: Similar conditions with sunny intervals, especially in the afternoon.\n\n### Tips for Maximizing Solar Power Usage\n\n1. **Schedule High-Energy Activities**:\n   - Plan to run high-energy appliances (like washing machines, dishwashers, and electric vehicles) during peak solar hours, which are typically between 10 AM and 3 PM. This is when solar irradiance is highest.\n\n2. **Monitor Solar Production**:\n   - Keep an eye on your solar production throughout the day. If you have a solar monitoring system, check the output and adjust your energy usage accordingly.\n\n3. **Use Energy Storage**:\n   - If you have a battery storage system, charge it during peak solar hours. This will allow you to use stored energy during the evening when solar production drops.\n\n4. **Reduce Energy Consumption**:\n   - Turn off non-essential appliances and lights during peak solar hours to maximize the use of solar energy.\n\n5. **Optimize Solar Panel Angle**:\n   - If possible, adjust the angle of your solar panels to capture more sunlight, especially if you notice that the sun's position changes significantly throughout the day.\n\n6. **Consider Solar Water Heating**:\n   - If you have a solar water heating system, use it to heat water during the day when solar energy is abundant.\n\n7. **Plan for Cloudy Conditions**:\n   - Be aware that cloud cover can affect solar production. If the forecast indicates cloudy periods, adjust your energy usage accordingly.\n\nBy following these tips, you can make the most of your solar power this weekend and reduce your reliance on grid electricity. Enjoy the sunny days!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 375, 'prompt_tokens': 2182, 'total_tokens': 2557, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsVx2R0Qduckn4KTw8ypCdSUuIhUv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019b6fe0-e2df-7f80-b8ec-f9659fa2019d-0', usage_metadata={'input_tokens': 2182, 'output_tokens': 375, 'total_tokens': 2557, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_weather_forecast', 'get_solar_power_tips'],
#   'expected_response': 'The response should include strategies for maximizing solar power usage',
#   'timestamp': '2025-12-30T15:29:37.134030'},
#  {'test_id': 'cost_savings_calculation_1',
#   'question': 'How much can I save by adjusting my thermostat by 2 degrees?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='0810bb92-0dca-4589-9c02-c6fd5fd00c75'),
#     HumanMessage(content='How much can I save by adjusting my thermostat by 2 degrees?', additional_kwargs={}, response_metadata={}, id='afe69f7e-6301-4990-bdf1-7f71ab7d8eb7'),
#     AIMessage(content='To calculate potential savings from adjusting your thermostat by 2 degrees, I need to know your current energy usage for heating or cooling (in kWh) and the price per kWh you are currently paying. \n\nIf you have that information, please provide it, or I can look up your recent energy usage data if you prefer.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 905, 'total_tokens': 972, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CsVxBcH51IkaHkJAsfeVSjVq4MGL4', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019b6fe1-076f-7213-9f94-6a084006f07a-0', usage_metadata={'input_tokens': 905, 'output_tokens': 67, 'total_tokens': 972, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['calculate_energy_savings'],
#   'expected_response': 'The response should provide a detailed cost savings calculation',
#   'timestamp': '2025-12-30T15:29:39.430232'},
#  {'test_id': 'ev_charging_2',
#   'question': 'Is it cheaper to charge my EV at night or during the day?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='478b6685-7c2c-463f-89e1-181dc8016ad1'),
#     HumanMessage(content='Is it cheaper to charge my EV at night or during the day?', additional_kwargs={}, response_metadata={}, id='ad10a880-e071-4199-b77b-58d51fb0e571'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 905, 'total_tokens': 918, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CsVxDugN5F3tSkPZ4WK8AUHM0mWFV', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019b6fe1-1067-7fd3-90d5-4c95312ccb8f-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {}, 'id': 'call_OEJJRyikbIM9QmPIjnlwuQzf', 'type': 'tool_call'}], usage_metadata={'input_tokens': 905, 'output_tokens': 13, 'total_tokens': 918, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"date": "2025-12-30", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.117, "period": "off-peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.142, "period": "off-peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.146, "period": "off-peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.121, "period": "off-peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.147, "period": "off-peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.119, "period": "off-peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.189, "period": "peak", "demand_charge": 0.075}, {"hour": 7, "rate": 0.184, "period": "peak", "demand_charge": 0.082}, {"hour": 8, "rate": 0.224, "period": "peak", "demand_charge": 0.064}, {"hour": 9, "rate": 0.207, "period": "peak", "demand_charge": 0.071}, {"hour": 10, "rate": 0.204, "period": "peak", "demand_charge": 0.078}, {"hour": 11, "rate": 0.223, "period": "peak", "demand_charge": 0.067}, {"hour": 12, "rate": 0.216, "period": "peak", "demand_charge": 0.093}, {"hour": 13, "rate": 0.2, "period": "peak", "demand_charge": 0.085}, {"hour": 14, "rate": 0.18, "period": "peak", "demand_charge": 0.089}, {"hour": 15, "rate": 0.214, "period": "peak", "demand_charge": 0.086}, {"hour": 16, "rate": 0.204, "period": "peak", "demand_charge": 0.061}, {"hour": 17, "rate": 0.187, "period": "peak", "demand_charge": 0.08}, {"hour": 18, "rate": 0.203, "period": "peak", "demand_charge": 0.06}, {"hour": 19, "rate": 0.191, "period": "peak", "demand_charge": 0.073}, {"hour": 20, "rate": 0.195, "period": "peak", "demand_charge": 0.085}, {"hour": 21, "rate": 0.191, "period": "peak", "demand_charge": 0.054}, {"hour": 22, "rate": 0.114, "period": "off-peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.114, "period": "off-peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='7e1ccd1a-8aee-4b22-a3fd-6df174f9f1a0', tool_call_id='call_OEJJRyikbIM9QmPIjnlwuQzf'),
#     AIMessage(content="To determine whether it's cheaper to charge your EV at night or during the day, let's look at the electricity rates for both periods:\n\n### Night (Off-Peak Rates)\n- **12 AM - 5 AM**: Rates range from $0.117 to $0.147 per kWh\n- **10 PM - 11 PM**: Rates are $0.114 per kWh\n\n### Day (Peak Rates)\n- **6 AM - 10 AM**: Rates range from $0.184 to $0.224 per kWh\n- **10 AM - 6 PM**: Rates range from $0.2 to $0.223 per kWh\n\n### Summary\n- **Night (Off-Peak)**: Average rate is approximately $0.125 per kWh.\n- **Day (Peak)**: Average rate is approximately $0.2 per kWh.\n\n### Conclusion\nCharging your EV at night is significantly cheaper than during the day. It's advisable to take advantage of the off-peak rates to save on your electricity costs.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 218, 'prompt_tokens': 1709, 'total_tokens': 1927, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsVxFZwj9yaXEx0C0jKu66OyjswWP', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019b6fe1-165a-7932-b244-3a183e760178-0', usage_metadata={'input_tokens': 1709, 'output_tokens': 218, 'total_tokens': 1927, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_electricity_prices'],
#   'expected_response': 'The response should compare costs and provide a recommendation',
#   'timestamp': '2025-12-30T15:29:45.856671'},
#  {'test_id': 'thermostat_setting_2',
#   'question': 'What thermostat settings should I use in winter to save energy?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='188ad6f9-ea02-46bd-a59b-ecba65ab71e0'),
#     HumanMessage(content='What thermostat settings should I use in winter to save energy?', additional_kwargs={}, response_metadata={}, id='4ef601d0-aa9b-4036-88fe-ab52e562ba0c'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 903, 'total_tokens': 928, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CsVxKxOdPSOxQCeoCwzwB56PGvdhB', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019b6fe1-2982-7c13-8eec-b6aa922182f7-0', tool_calls=[{'name': 'search_energy_tips', 'args': {'query': 'thermostat settings winter', 'max_results': 5}, 'id': 'call_6T40Qg7zunXJ7wEyiO3wC4ae', 'type': 'tool_call'}], usage_metadata={'input_tokens': 903, 'output_tokens': 25, 'total_tokens': 928, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"query": "thermostat settings winter", "total_results": 5, "tips": [{"rank": 1, "content": "Saving energy at home can be simple and effective. Turn off lights when not in use and unplug devices that draw standby power. Use natural lighting during the day and replace incandescent bulbs with energy-efficient LEDs. Keep appliances clean and well-maintained to ensure they operate efficiently.\\n\\nSmart thermostats can save up to 10% on heating and cooling costs by automatically adjusting temperatures when you\'re away. Set your thermostat to 68°F in winter and 78°F in summer for optimal energy savings.\\n\\nWash clothes in cold water and only run full loads. Use the dryer\'s moisture sensor instead of timed drying. Clean the lint filter after every load to improve efficiency.\\n\\nSeal air leaks around windows and doors with weatherstripping or caulk. Add insulation to attics and walls to reduce heating and cooling needs.\\n\\nUse power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.", "source": "/Users/ahsan/Documents/Udemy/energy-advisor/ecohome-starter/data/documents/tip_energy_savings.txt", "relevance_score": "high"}, {"rank": 2, "content": "Saving energy at home can be simple and effective. Turn off lights when not in use and unplug devices that draw standby power. Use natural lighting during the day and replace incandescent bulbs with energy-efficient LEDs. Keep appliances clean and well-maintained to ensure they operate efficiently.\\n\\nSmart thermostats can save up to 10% on heating and cooling costs by automatically adjusting temperatures when you\'re away. Set your thermostat to 68°F in winter and 78°F in summer for optimal energy savings.\\n\\nWash clothes in cold water and only run full loads. Use the dryer\'s moisture sensor instead of timed drying. Clean the lint filter after every load to improve efficiency.\\n\\nSeal air leaks around windows and doors with weatherstripping or caulk. Add insulation to attics and walls to reduce heating and cooling needs.\\n\\nUse power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.", "source": "/Users/ahsan/Documents/Udemy/energy-advisor/ecohome-starter/data/documents/tip_energy_savings.txt", "relevance_score": "high"}, {"rank": 3, "content": "Use power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.\\n\\nConsider energy-efficient appliances when replacing old ones. Look for ENERGY STAR certified products that use 10-50% less energy than standard models.\\n\\nPlant trees or install awnings to provide shade for your home during summer months. This can reduce cooling costs by up to 25%.\\n\\nUse ceiling fans to circulate air and make rooms feel cooler, allowing you to raise the thermostat temperature by 4°F without discomfort.", "source": "/Users/ahsan/Documents/Udemy/energy-advisor/ecohome-starter/data/documents/tip_energy_savings.txt", "relevance_score": "medium"}, {"rank": 4, "content": "Use power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.\\n\\nConsider energy-efficient appliances when replacing old ones. Look for ENERGY STAR certified products that use 10-50% less energy than standard models.\\n\\nPlant trees or install awnings to provide shade for your home during summer months. This can reduce cooling costs by up to 25%.\\n\\nUse ceiling fans to circulate air and make rooms feel cooler, allowing you to raise the thermostat temperature by 4°F without discomfort.", "source": "/Users/ahsan/Documents/Udemy/energy-advisor/ecohome-starter/data/documents/tip_energy_savings.txt", "relevance_score": "medium"}, {"rank": 5, "content": "Dishwasher Best Practices:\\n- Only run when completely full\\n- Use the ...
#     AIMessage(content="To save energy during winter, consider the following thermostat settings and tips:\n\n1. **Set Your Thermostat to 68°F**: This is the optimal temperature for energy savings during winter. Lowering the thermostat by just a few degrees can lead to significant savings.\n\n2. **Use a Smart Thermostat**: Smart thermostats can automatically adjust temperatures when you're away, potentially saving you up to 10% on heating costs.\n\n3. **Seal Air Leaks**: Ensure that windows and doors are properly sealed to prevent drafts. This will help maintain the desired temperature without overworking your heating system.\n\n4. **Add Insulation**: Insulating attics and walls can reduce the need for heating, keeping your home warmer with less energy.\n\n5. **Utilize Natural Heat**: Open curtains during sunny days to let in natural warmth and close them at night to retain heat.\n\nBy implementing these strategies, you can effectively reduce your energy consumption and lower your heating bills during the winter months.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 201, 'prompt_tokens': 2012, 'total_tokens': 2213, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsVxMi3mTvroB8vHWtkY1x8G8nvUy', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019b6fe1-33c0-7cf0-9755-a651a9bc4a46-0', usage_metadata={'input_tokens': 2012, 'output_tokens': 201, 'total_tokens': 2213, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_energy_saving_tips'],
#   'expected_response': 'The response should include recommended temperature settings and energy-saving tips',
#   'timestamp': '2025-12-30T15:29:52.920818'},
#  {'test_id': 'appliance_scheduling_2',
#   'question': 'When is the best time to run my washing machine to save energy?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='0c96f75b-376a-4999-a00f-4f5e6a64c9c8'),
#     HumanMessage(content='When is the best time to run my washing machine to save energy?', additional_kwargs={}, response_metadata={}, id='cc4165fa-90de-4e80-9e3a-ffc6b06b0ff5'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 905, 'total_tokens': 918, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CsVxR2pnQyoVXIbdjV4U866zTw1g6', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019b6fe1-451a-7b81-a1ad-b7fab91f70a1-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {}, 'id': 'call_kgaRiNnRfLffqDzcuHjPXcza', 'type': 'tool_call'}], usage_metadata={'input_tokens': 905, 'output_tokens': 13, 'total_tokens': 918, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"date": "2025-12-30", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.113, "period": "off-peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.139, "period": "off-peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.114, "period": "off-peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.146, "period": "off-peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.126, "period": "off-peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.146, "period": "off-peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.222, "period": "peak", "demand_charge": 0.056}, {"hour": 7, "rate": 0.207, "period": "peak", "demand_charge": 0.089}, {"hour": 8, "rate": 0.206, "period": "peak", "demand_charge": 0.057}, {"hour": 9, "rate": 0.198, "period": "peak", "demand_charge": 0.091}, {"hour": 10, "rate": 0.219, "period": "peak", "demand_charge": 0.07}, {"hour": 11, "rate": 0.186, "period": "peak", "demand_charge": 0.099}, {"hour": 12, "rate": 0.202, "period": "peak", "demand_charge": 0.073}, {"hour": 13, "rate": 0.185, "period": "peak", "demand_charge": 0.052}, {"hour": 14, "rate": 0.225, "period": "peak", "demand_charge": 0.083}, {"hour": 15, "rate": 0.218, "period": "peak", "demand_charge": 0.061}, {"hour": 16, "rate": 0.197, "period": "peak", "demand_charge": 0.055}, {"hour": 17, "rate": 0.215, "period": "peak", "demand_charge": 0.085}, {"hour": 18, "rate": 0.19, "period": "peak", "demand_charge": 0.056}, {"hour": 19, "rate": 0.198, "period": "peak", "demand_charge": 0.054}, {"hour": 20, "rate": 0.186, "period": "peak", "demand_charge": 0.086}, {"hour": 21, "rate": 0.224, "period": "peak", "demand_charge": 0.098}, {"hour": 22, "rate": 0.145, "period": "off-peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.15, "period": "off-peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='7ea0a454-e4da-4c61-8b41-34058a95c215', tool_call_id='call_kgaRiNnRfLffqDzcuHjPXcza'),
#     AIMessage(content="To save energy and reduce costs when running your washing machine, it's best to operate it during off-peak hours when electricity rates are lower. \n\nHere are the off-peak hours and their corresponding rates:\n\n- **12 AM - 1 AM**: $0.113\n- **1 AM - 2 AM**: $0.139\n- **2 AM - 3 AM**: $0.114\n- **3 AM - 4 AM**: $0.146\n- **4 AM - 5 AM**: $0.126\n- **5 AM - 6 AM**: $0.146\n- **10 PM - 11 PM**: $0.145\n- **11 PM - 12 AM**: $0.150\n\nThe best time to run your washing machine would be between **12 AM and 5 AM** for the lowest rates.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 186, 'prompt_tokens': 1709, 'total_tokens': 1895, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsVxSNmJrT3wN7sKCvzBf8snFZbyd', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019b6fe1-49c0-7cf0-aaae-488bf83f025d-0', usage_metadata={'input_tokens': 1709, 'output_tokens': 186, 'total_tokens': 1895, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_electricity_prices'],
#   'expected_response': 'The response should provide specific time slots for running the washing machine',
#   'timestamp': '2025-12-30T15:29:58.711512'},
#  {'test_id': 'solar_power_maximization_2',
#   'question': 'What are the best practices for using solar power during cloudy days?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='025c7330-682a-4e8b-8ec6-b71001533c14'),
#     HumanMessage(content='What are the best practices for using solar power during cloudy days?', additional_kwargs={}, response_metadata={}, id='5183bff4-9348-4697-aa3c-ea4c3c448797'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 904, 'total_tokens': 928, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CsVxXKvIsd16cNzpFGN1HzzRDKHCa', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019b6fe1-5bb9-76f3-8e22-e08edf16f975-0', tool_calls=[{'name': 'search_energy_tips', 'args': {'query': 'solar power cloudy days', 'max_results': 5}, 'id': 'call_CDMYmNPHNUup1qxmYNiUd3k2', 'type': 'tool_call'}], usage_metadata={'input_tokens': 904, 'output_tokens': 24, 'total_tokens': 928, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"query": "solar power cloudy days", "total_results": 5, "tips": [{"rank": 1, "content": "Large devices like electric vehicles, washing machines and dishwashers often support delayed start or timer functions. Schedule these devices to run outside of peak electricity pricing hours or during periods of high solar generation. Consult your device manual for specific scheduling instructions.\\n\\nElectric Vehicle Charging:\\n- Charge during off-peak hours (typically 11 PM to 6 AM) to save money\\n- Use Level 2 charging at home for faster charging when needed\\n- Set charging to complete just before you need the vehicle\\n- Consider charging during peak solar generation hours if you have solar panels\\n\\nWashing Machine Optimization:\\n- Run full loads to maximize efficiency\\n- Use cold water for most loads to save energy\\n- Schedule loads during off-peak hours or when solar generation is high\\n- Clean the machine regularly to maintain efficiency", "source": "/Users/ahsan/Documents/Udemy/energy-advisor/ecohome-starter/data/documents/tip_device_best_practices.txt", "relevance_score": "high"}, {"rank": 2, "content": "Large devices like electric vehicles, washing machines and dishwashers often support delayed start or timer functions. Schedule these devices to run outside of peak electricity pricing hours or during periods of high solar generation. Consult your device manual for specific scheduling instructions.\\n\\nElectric Vehicle Charging:\\n- Charge during off-peak hours (typically 11 PM to 6 AM) to save money\\n- Use Level 2 charging at home for faster charging when needed\\n- Set charging to complete just before you need the vehicle\\n- Consider charging during peak solar generation hours if you have solar panels\\n\\nWashing Machine Optimization:\\n- Run full loads to maximize efficiency\\n- Use cold water for most loads to save energy\\n- Schedule loads during off-peak hours or when solar generation is high\\n- Clean the machine regularly to maintain efficiency", "source": "/Users/ahsan/Documents/Udemy/energy-advisor/ecohome-starter/data/documents/tip_device_best_practices.txt", "relevance_score": "high"}, {"rank": 3, "content": "Use power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.\\n\\nConsider energy-efficient appliances when replacing old ones. Look for ENERGY STAR certified products that use 10-50% less energy than standard models.\\n\\nPlant trees or install awnings to provide shade for your home during summer months. This can reduce cooling costs by up to 25%.\\n\\nUse ceiling fans to circulate air and make rooms feel cooler, allowing you to raise the thermostat temperature by 4°F without discomfort.", "source": "/Users/ahsan/Documents/Udemy/energy-advisor/ecohome-starter/data/documents/tip_energy_savings.txt", "relevance_score": "medium"}, {"rank": 4, "content": "Use power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.\\n\\nConsider energy-efficient appliances when replacing old ones. Look for ENERGY STAR certified products that use 10-50% less energy than standard models.\\n\\nPlant trees or install awnings to provide shade for your home during summer months. This can reduce cooling costs by up to 25%.\\n\\nUse ceiling fans to circulate air and make rooms feel cooler, allowing you to raise the thermostat temperature by 4°F without discomfort.", "source": "/Users/ahsan/Documents/Udemy/energy-advisor/ecohome-starter/data/documents/tip_energy_savings.txt", "relevance_score": "medium"}, {"rank": 5, "content": "Saving energy at home can be simple and effective. Turn off lights when not in use and unplug devices that draw standby power. Use natural lighting during the day and replace incandescent bulbs with energy-efficient LEDs. Keep appliances clean and well-maintained to ensure they operate efficiently.\\n\\nSmar ...
#     AIMessage(content='Here are some best practices for using solar power during cloudy days:\n\n1. **Schedule Large Appliances**: Use the delayed start or timer functions on large devices like electric vehicles, washing machines, and dishwashers. Schedule these to run during periods of high solar generation or outside of peak electricity pricing hours.\n\n   - **Electric Vehicle Charging**:\n     - Charge during off-peak hours (typically 11 PM to 6 AM) to save money.\n     - Use Level 2 charging at home for faster charging when needed.\n     - Set charging to complete just before you need the vehicle.\n     - Consider charging during peak solar generation hours if you have solar panels.\n\n   - **Washing Machine Optimization**:\n     - Run full loads to maximize efficiency.\n     - Use cold water for most loads to save energy.\n     - Schedule loads during off-peak hours or when solar generation is high.\n     - Clean the machine regularly to maintain efficiency.\n\n2. **Reduce Phantom Load**: Use power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.\n\n3. **Consider Energy-Efficient Appliances**: When replacing old appliances, look for ENERGY STAR certified products that use 10-50% less energy than standard models.\n\n4. **Utilize Natural Lighting**: During the day, make use of natural lighting instead of relying on electric lights.\n\n5. **Maintain Appliances**: Keep appliances clean and well-maintained to ensure they operate efficiently. For example, clean the lint filter in your dryer after every load to improve efficiency.\n\nBy implementing these practices, you can maximize your solar energy usage even on cloudy days!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 340, 'prompt_tokens': 1969, 'total_tokens': 2309, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CsVxaj0ug0agSPF7ArX9Sn20uztQu', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019b6fe1-66ea-7280-8c83-59c9ef63654b-0', usage_metadata={'input_tokens': 1969, 'output_tokens': 340, 'total_tokens': 2309, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_solar_power_tips'],
#   'expected_response': 'The response should include strategies for maximizing solar power usage on cloudy days',
#   'timestamp': '2025-12-30T15:30:09.877314'},
#  {'test_id': 'cost_savings_calculation_2',
#   'question': 'How much can I save by using energy-efficient appliances?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='24d1c3a9-9741-4c14-8377-7106e854775d'),
#     HumanMessage(content='How much can I save by using energy-efficient appliances?', additional_kwargs={}, response_metadata={}, id='9c274b98-f0d1-405b-a218-24b984246134'),
#     AIMessage(content="To provide you with an accurate estimate of potential savings from using energy-efficient appliances, I need to know:\n\n1. The type of appliance (e.g., refrigerator, washing machine, etc.).\n2. The current energy usage of your existing appliance in kWh.\n3. The expected energy usage of the energy-efficient appliance in kWh.\n4. The price per kWh you are currently paying for electricity (if you know it).\n\nIf you don't have the exact numbers, I can provide general estimates based on common appliances. Let me know how you'd like to proceed!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 114, 'prompt_tokens': 902, 'total_tokens': 1016, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CsVxijCzn6VezDmqJpOsIfeSCntLH', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019b6fe1-8757-7300-80b1-0e16a332e4bc-0', usage_metadata={'input_tokens': 902, 'output_tokens': 114, 'total_tokens': 1016, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['calculate_energy_savings'],
#   'expected_response': 'The response should provide a detailed cost savings calculation based on appliance efficiency',
#   'timestamp': '2025-12-30T15:30:13.097072'}]

# %% [markdown]
# ## 4. Evaluate Responses

# %%
# TODO: Implement evaluation functions
# Create functions to evaluate:
# - Final Response
# - Tool usage

# %%
# TODO: Create a response evaluator
def evaluate_response(final_response, expected_response):
    """Evaluate a single response against expected response"""
    # Simple keyword matching for demonstration
    expected_keywords = expected_response.lower().split()
    response_text = final_response.lower()
    
    match_count = sum(1 for kw in expected_keywords if kw in response_text)
    score = match_count / len(expected_keywords) if expected_keywords else 0
    
    return score

# %%
# TODO: Create a tool udage evaluator
def evaluate_tool_usage(messages, expected_tools):
    """Evaluate if the right tools were used"""
    print("Evaluating tool usage...")

    for msg in messages:
        print(f"Message: {msg.content}, Name: {msg.name}")

    # get all used tool names from messages
    used_tools = [msg.name for msg in messages if msg.model_dump().get("tool_call_id")]
    used_tool_set = set(used_tools)
    expected_tool_set = set(expected_tools)
    
    correct_tools = used_tool_set.intersection(expected_tool_set)
    missing_tools = expected_tool_set.difference(used_tool_set)
    extra_tools = used_tool_set.difference(expected_tool_set)
    
    return {
        "used_tools": list(used_tool_set),
        "correct_tools": list(correct_tools),
        "missing_tools": list(missing_tools),
        "extra_tools": list(extra_tools),
    }

# %%
# TODO: Generate a comprehensive evaluation report
# Calculate overall scores and metrics
# Identify strengths and weaknesses
# Provide recommendations for improvement
def generate_evaluation_report(test_results):
    total_response_score = 0
    total_tool_correct = 0
    total_tool_missing = 0
    total_tool_extra = 0
    
    for result in test_results:
        # Evaluate response
        final_response = result['response']['messages'][-1].content if isinstance(result['response'], dict) else ""
        response_score = evaluate_response(
            final_response=final_response,
            expected_response=result['expected_response']
        )
        total_response_score += response_score
        
        # Evaluate tool usage
        messages = result['response']['messages'] if isinstance(result['response'], dict) else []
        tool_evaluation = evaluate_tool_usage(
            messages=messages,
            expected_tools=result['expected_tools']
        )
        
        total_tool_correct += len(tool_evaluation['correct_tools'])
        total_tool_missing += len(tool_evaluation['missing_tools'])
        total_tool_extra += len(tool_evaluation['extra_tools'])
        
        # Print individual test results
        print(f"Test ID: {result['test_id']}")
        print(f"Response Score: {response_score:.2f}")
        print(f"Tool Usage: {tool_evaluation}")
        print("-" * 50)
    
    num_tests = len(test_results)
    avg_response_score = total_response_score / num_tests if num_tests > 0 else 0
    
    print("\n=== Evaluation Summary ===")
    print(f"Average Response Score: {avg_response_score:.2f}")
    print(f"Total Correct Tools Used: {total_tool_correct}")
    print(f"Total Missing Tools: {total_tool_missing}")
    print(f"Total Extra Tools: {total_tool_extra}")

# %%
generate_evaluation_report(test_results)
# Out:
# Evaluating tool usage...
# Message: Location: San Francisco, CA, Name: None
# Message: When should I charge my electric car tomorrow to minimize cost and maximize solar power?, Name: None
# Message: , Name: energy_advisor
# Message: {"date": "2023-10-07", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.107, "period": "off-peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.138, "period": "off-peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.114, "period": "off-peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.12, "period": "off-peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.138, "period": "off-peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.135, "period": "off-peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.208, "period": "peak", "demand_charge": 0.086}, {"hour": 7, "rate": 0.193, "period": "peak", "demand_charge": 0.052}, {"hour": 8, "rate": 0.198, "period": "peak", "demand_charge": 0.064}, {"hour": 9, "rate": 0.18, "period": "peak", "demand_charge": 0.088}, {"hour": 10, "rate": 0.218, "period": "peak", "demand_charge": 0.099}, {"hour": 11, "rate": 0.211, "period": "peak", "demand_charge": 0.063}, {"hour": 12, "rate": 0.215, "period": "peak", "demand_charge": 0.073}, {"hour": 13, "rate": 0.22, "period": "peak", "demand_charge": 0.055}, {"hour": 14, "rate": 0.209, "period": "peak", "demand_charge": 0.09}, {"hour": 15, "rate": 0.186, "period": "peak", "demand_charge": 0.064}, {"hour": 16, "rate": 0.21, "period": "peak", "demand_charge": 0.09}, {"hour": 17, "rate": 0.217, "period": "peak", "demand_charge": 0.085}, {"hour": 18, "rate": 0.224, "period": "peak", "demand_charge": 0.054}, {"hour": 19, "rate": 0.217, "period": "peak", "demand_charge": 0.077}, {"hour": 20, "rate": 0.211, "period": "peak", "demand_charge": 0.056}, {"hour": 21, "rate": 0.213, "period": "peak", "demand_charge": 0.061}, {"hour": 22, "rate": 0.106, "period": "off-peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.146, "period": "off-peak", "demand_charge": 0.0}]}, Name: get_electricity_prices
# Message: {"location": "San Francisco, CA", "forecast_days": 1, "current": {"temperature_c": 26.2, "condition": "sunny", "humidity": 30, "wind_speed": 4.6}, "hourly": [{"hour": 0, "temperature_c": 28.4, "condition": "sunny", "solar_irradiance": 715.2, "humidity": 56, "wind_speed": 11.1}, {"hour": 1, "temperature_c": 25.7, "condition": "partly_cloudy", "solar_irradiance": 44.8, "humidity": 72, "wind_speed": 13.7}, {"hour": 2, "temperature_c": 21.5, "condition": "sunny", "solar_irradiance": 160.8, "humidity": 37, "wind_speed": 2.1}, {"hour": 3, "temperature_c": 25.0, "condition": "sunny", "solar_irradiance": 773.4, "humidity": 53, "wind_speed": 6.7}, {"hour": 4, "temperature_c": 27.1, "condition": "partly_cloudy", "solar_irradiance": 817.2, "humidity": 80, "wind_speed": 9.6}, {"hour": 5, "temperature_c": 21.8, "condition": "sunny", "solar_irradiance": 479.9, "humidity": 51, "wind_speed": 5.0}, {"hour": 6, "temperature_c": 18.0, "condition": "cloudy", "solar_irradiance": 517.0, "humidity": 40, "wind_speed": 3.9}, {"hour": 7, "temperature_c": 23.5, "condition": "cloudy", "solar_irradiance": 894.2, "humidity": 77, "wind_speed": 3.0}, {"hour": 8, "temperature_c": 21.3, "condition": "cloudy", "solar_irradiance": 627.5, "humidity": 40, "wind_speed": 13.8}, {"hour": 9, "temperature_c": 29.2, "condition": "partly_cloudy", "solar_irradiance": 864.7, "humidity": 50, "wind_speed": 12.3}, {"hour": 10, "temperature_c": 17.3, "condition": "sunny", "solar_irradiance": 752.5, "humidity": 53, "wind_speed": 4.1}, {"hour": 11, "temperature_c": 27.7, "condition": "cloudy", "solar_irradiance": 682.5, "humidity": 75, "wind_speed": 14.6}, {"hour": 12, "temperature_c": 25.6, "condition": "sunny", "solar_irradiance": 285.1, "humidity": 50, "wind_speed": 9.6}, {"hour": 13, "temperature_c": 19.3, "condition": "sunny", "solar_irradiance": 989.0, "humidity": 55, "wind_speed": 4.8}, {"hour": 14, "temperature_c": 27.3, "condition": "partly_cloudy", "solar_irradiance": 896.0, "humidity": 38, "wind_speed": 0.5}, {"hour": 15, "temperature_c": 21.3, "condition": "cloudy", "solar_irradiance": 280.3, "humidity": 64, "wind_speed": 1.8}, {"hour": 16, "temperature_c": 22.7, "condition": "cloudy", "solar_irradiance": 452.4, "humidity": 71, "wind_speed": 13.9}, {"hour": 17, "temperature_c": 24.8, "condition": "cloudy", "solar_irradiance": 67.9, "humidity": 67, "wind_speed": 13.7}, {"hour": 18, "temperature_c": 26.7, "condition": "sunny", "solar_irradiance": 769.9, "humidity": 31, "wind_speed": 13.7}, {"hour": 19, "temperature_c": 16.8, "condition": "partly_cloudy", "solar_irradiance": 556.3, "humidity": 61, "wind_speed": 4.5}, {"hour": 20, "temperature_c": 17.4, "condition": "cloudy", "solar_irradiance": 680.5, "humidity": 42, "wind_speed": 5.3}, {"hour": 21, "temperature_c": 24.8, "condition": "cloudy", "solar_irradiance": 382.0, "humidity": 31, "wind_speed": 2.6}, {"hour": 22, "temperature_c": 28.5, "condition": "partly_cloudy", "solar_irradiance": 111.6, "humidity": 32, "wind_speed": 8.8}, {"hour": 23, "temperature_c": 15.1, "condition": "partly_cloudy", "solar_irradiance": 224.4, "humidity": 80, "wind_speed": 2.1}]}, Name: get_weather_forecast
# Message: To minimize costs and maximize solar power when charging your electric car tomorrow (October 7, 2023), here are the key insights:
#
# ### Electricity Pricing (Time of Use)
# - **Off-Peak Rates** (Lower cost):
#   - 12 AM - 6 AM: $0.107 to $0.208 per kWh
#   - 10 PM - 11 PM: $0.106 to $0.146 per kWh
# - **Peak Rates** (Higher cost):
#   - 6 AM - 10 PM: $0.180 to $0.224 per kWh
#
# ### Solar Power Generation Forecast
# - **Best Solar Generation Hours**:
#   - **12 PM - 2 PM**: High solar irradiance, especially at 1 PM (989.0 W/m²).
#   - **9 AM - 11 AM**: Good solar generation, peaking at 9 AM (864.7 W/m²).
#
# ### Recommendations
# 1. **Charge During Off-Peak Hours**:
#    - **Best Time**: Start charging after 10 PM tonight or early in the morning before 6 AM to take advantage of lower rates.
#
# 2. **Maximize Solar Power**:
#    - If you prefer to charge during the day, consider charging between **12 PM and 2 PM** when solar generation is at its peak. However, be aware that the rates during this time will be higher (around $0.215 to $0.22 per kWh).
#
# ### Conclusion
# - **Ideal Charging Strategy**: Charge your electric car overnight (after 10 PM) to benefit from the lowest rates, or charge during the peak solar hours (12 PM - 2 PM) if you want to utilize solar energy, but expect to pay more for the electricity., Name: energy_advisor
# Test ID: ev_charging_1
# Response Score: 0.45
# Tool Usage: {'used_tools': ['get_weather_forecast', 'get_electricity_prices'], 'correct_tools': ['get_weather_forecast', 'get_electricity_prices'], 'missing_tools': [], 'extra_tools': []}
# --------------------------------------------------
# Evaluating tool usage...
# Message: Location: San Francisco, CA, Name: None
# Message: What is the optimal thermostat setting for my home during a heatwave?, Name: None
# Message: During a heatwave, it's important to keep your home cool while also being energy-efficient. Here are some optimal thermostat settings and tips:
#
# 1. **Set the Thermostat Higher**: Aim to set your thermostat to around 78°F (26°C) when you're at home. This helps to keep your home comfortable without overworking your air conditioning system.
#
# 2. **Use Fans**: If you have ceiling fans, use them to help circulate cool air. You can set the thermostat a bit higher if you use fans, as they can make you feel cooler.
#
# 3. **Avoid Extreme Temperature Changes**: Setting the thermostat too low (like 70°F or lower) can lead to excessive energy use and strain on your AC unit.
#
# 4. **Utilize Programmable Thermostats**: If you have a programmable thermostat, set it to increase the temperature when you're not home and cool down before you return.
#
# 5. **Close Blinds and Curtains**: Keep blinds and curtains closed during the hottest parts of the day to block out heat from the sun.
#
# 6. **Consider Nighttime Cooling**: If temperatures drop at night, consider turning the thermostat up and using natural ventilation to cool your home.
#
# Would you like more specific tips based on your current energy usage or weather conditions?, Name: energy_advisor
# Test ID: thermostat_setting_1
# Response Score: 0.50
# Tool Usage: {'used_tools': [], 'correct_tools': [], 'missing_tools': ['get_weather_forecast', 'get_energy_saving_tips'], 'extra_tools': []}
# --------------------------------------------------
# Evaluating tool usage...
# Message: Location: San Francisco, CA, Name: None
# Message: When should I run my dishwasher to save on energy costs?, Name: None
# Message: , Name: energy_advisor
# Message: {"date": "2025-12-30", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.122, "period": "off-peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.121, "period": "off-peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.11, "period": "off-peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.115, "period": "off-peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.129, "period": "off-peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.115, "period": "off-peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.199, "period": "peak", "demand_charge": 0.086}, {"hour": 7, "rate": 0.216, "period": "peak", "demand_charge": 0.083}, {"hour": 8, "rate": 0.221, "period": "peak", "demand_charge": 0.062}, {"hour": 9, "rate": 0.223, "period": "peak", "demand_charge": 0.086}, {"hour": 10, "rate": 0.207, "period": "peak", "demand_charge": 0.073}, {"hour": 11, "rate": 0.195, "period": "peak", "demand_charge": 0.053}, {"hour": 12, "rate": 0.181, "period": "peak", "demand_charge": 0.08}, {"hour": 13, "rate": 0.224, "period": "peak", "demand_charge": 0.057}, {"hour": 14, "rate": 0.186, "period": "peak", "demand_charge": 0.061}, {"hour": 15, "rate": 0.221, "period": "peak", "demand_charge": 0.07}, {"hour": 16, "rate": 0.198, "period": "peak", "demand_charge": 0.059}, {"hour": 17, "rate": 0.186, "period": "peak", "demand_charge": 0.08}, {"hour": 18, "rate": 0.218, "period": "peak", "demand_charge": 0.088}, {"hour": 19, "rate": 0.197, "period": "peak", "demand_charge": 0.057}, {"hour": 20, "rate": 0.19, "period": "peak", "demand_charge": 0.066}, {"hour": 21, "rate": 0.213, "period": "peak", "demand_charge": 0.081}, {"hour": 22, "rate": 0.117, "period": "off-peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.134, "period": "off-peak", "demand_charge": 0.0}]}, Name: get_electricity_prices
# Message: To save on energy costs when running your dishwasher, you should aim to operate it during off-peak hours when electricity rates are lower. Based on the current electricity pricing for San Francisco, here are the off-peak hours and their corresponding rates:
#
# - **12 AM - 6 AM**: Rates range from $0.11 to $0.129
# - **10 PM - 11 PM**: Rates are $0.117 and $0.134
#
# The best time to run your dishwasher would be between **12 AM and 6 AM** or after **10 PM**. This way, you can take advantage of the lower rates and save on your energy costs., Name: energy_advisor
# Test ID: appliance_scheduling_1
# Response Score: 0.64
# Tool Usage: {'used_tools': ['get_electricity_prices'], 'correct_tools': ['get_electricity_prices'], 'missing_tools': [], 'extra_tools': []}
# --------------------------------------------------
# Evaluating tool usage...
# Message: Location: San Francisco, CA, Name: None
# Message: How can I maximize my solar power usage this weekend?, Name: None
# Message: , Name: energy_advisor
# Message: {"location": "San Francisco, CA", "forecast_days": 3, "current": {"temperature_c": 24.6, "condition": "cloudy", "humidity": 52, "wind_speed": 4.2}, "hourly": [{"hour": 0, "temperature_c": 16.3, "condition": "partly_cloudy", "solar_irradiance": 947.7, "humidity": 78, "wind_speed": 9.1}, {"hour": 1, "temperature_c": 21.1, "condition": "cloudy", "solar_irradiance": 343.5, "humidity": 54, "wind_speed": 5.0}, {"hour": 2, "temperature_c": 20.2, "condition": "cloudy", "solar_irradiance": 711.0, "humidity": 56, "wind_speed": 2.8}, {"hour": 3, "temperature_c": 24.2, "condition": "cloudy", "solar_irradiance": 181.4, "humidity": 73, "wind_speed": 9.0}, {"hour": 4, "temperature_c": 17.6, "condition": "sunny", "solar_irradiance": 347.5, "humidity": 48, "wind_speed": 0.7}, {"hour": 5, "temperature_c": 26.7, "condition": "sunny", "solar_irradiance": 910.4, "humidity": 65, "wind_speed": 5.6}, {"hour": 6, "temperature_c": 25.7, "condition": "cloudy", "solar_irradiance": 351.6, "humidity": 34, "wind_speed": 1.5}, {"hour": 7, "temperature_c": 20.9, "condition": "cloudy", "solar_irradiance": 360.2, "humidity": 53, "wind_speed": 2.8}, {"hour": 8, "temperature_c": 21.8, "condition": "cloudy", "solar_irradiance": 197.5, "humidity": 32, "wind_speed": 4.1}, {"hour": 9, "temperature_c": 22.9, "condition": "partly_cloudy", "solar_irradiance": 391.1, "humidity": 34, "wind_speed": 14.9}, {"hour": 10, "temperature_c": 23.5, "condition": "sunny", "solar_irradiance": 437.6, "humidity": 65, "wind_speed": 7.3}, {"hour": 11, "temperature_c": 17.8, "condition": "cloudy", "solar_irradiance": 66.1, "humidity": 61, "wind_speed": 7.6}, {"hour": 12, "temperature_c": 29.6, "condition": "partly_cloudy", "solar_irradiance": 566.4, "humidity": 55, "wind_speed": 0.2}, {"hour": 13, "temperature_c": 27.6, "condition": "partly_cloudy", "solar_irradiance": 108.6, "humidity": 80, "wind_speed": 12.9}, {"hour": 14, "temperature_c": 27.4, "condition": "partly_cloudy", "solar_irradiance": 250.3, "humidity": 48, "wind_speed": 2.6}, {"hour": 15, "temperature_c": 16.4, "condition": "sunny", "solar_irradiance": 72.6, "humidity": 68, "wind_speed": 1.8}, {"hour": 16, "temperature_c": 15.4, "condition": "cloudy", "solar_irradiance": 685.7, "humidity": 74, "wind_speed": 1.9}, {"hour": 17, "temperature_c": 21.9, "condition": "cloudy", "solar_irradiance": 203.9, "humidity": 75, "wind_speed": 11.7}, {"hour": 18, "temperature_c": 21.3, "condition": "cloudy", "solar_irradiance": 774.4, "humidity": 35, "wind_speed": 11.8}, {"hour": 19, "temperature_c": 15.6, "condition": "sunny", "solar_irradiance": 219.0, "humidity": 60, "wind_speed": 8.9}, {"hour": 20, "temperature_c": 27.8, "condition": "sunny", "solar_irradiance": 608.6, "humidity": 57, "wind_speed": 0.3}, {"hour": 21, "temperature_c": 25.3, "condition": "sunny", "solar_irradiance": 910.4, "humidity": 40, "wind_speed": 1.2}, {"hour": 22, "temperature_c": 15.1, "condition": "sunny", "solar_irradiance": 825.9, "humidity": 37, "wind_speed": 14.9}, {"hour": 23, "temperature_c": 24.5, "condition": "partly_cloudy", "solar_irradiance": 52.2, "humidity": 55, "wind_speed": 9.2}]}, Name: get_weather_forecast
# Message: To maximize your solar power usage this weekend in San Francisco, here are some actionable tips based on the weather forecast:
#
# ### Weather Overview
# - **Saturday**: Expect partly cloudy conditions with peak solar irradiance around midday.
# - **Sunday**: Similar conditions with sunny intervals, especially in the afternoon.
#
# ### Tips for Maximizing Solar Power Usage
#
# 1. **Schedule High-Energy Activities**:
#    - Plan to run high-energy appliances (like washing machines, dishwashers, and electric vehicles) during peak solar hours, which are typically between 10 AM and 3 PM. This is when solar irradiance is highest.
#
# 2. **Monitor Solar Production**:
#    - Keep an eye on your solar production throughout the day. If you have a solar monitoring system, check the output and adjust your energy usage accordingly.
#
# 3. **Use Energy Storage**:
#    - If you have a battery storage system, charge it during peak solar hours. This will allow you to use stored energy during the evening when solar production drops.
#
# 4. **Reduce Energy Consumption**:
#    - Turn off non-essential appliances and lights during peak solar hours to maximize the use of solar energy.
#
# 5. **Optimize Solar Panel Angle**:
#    - If possible, adjust the angle of your solar panels to capture more sunlight, especially if you notice that the sun's position changes significantly throughout the day.
#
# 6. **Consider Solar Water Heating**:
#    - If you have a solar water heating system, use it to heat water during the day when solar energy is abundant.
#
# 7. **Plan for Cloudy Conditions**:
#    - Be aware that cloud cover can affect solar production. If the forecast indicates cloudy periods, adjust your energy usage accordingly.
#
# By following these tips, you can make the most of your solar power this weekend and reduce your reliance on grid electricity. Enjoy the sunny days!, Name: energy_advisor
# Test ID: solar_power_maximization_1
# Response Score: 0.60
# Tool Usage: {'used_tools': ['get_weather_forecast'], 'correct_tools': ['get_weather_forecast'], 'missing_tools': ['get_solar_power_tips'], 'extra_tools': []}
# --------------------------------------------------
# Evaluating tool usage...
# Message: Location: San Francisco, CA, Name: None
# Message: How much can I save by adjusting my thermostat by 2 degrees?, Name: None
# Message: To calculate potential savings from adjusting your thermostat by 2 degrees, I need to know your current energy usage for heating or cooling (in kWh) and the price per kWh you are currently paying.
#
# If you have that information, please provide it, or I can look up your recent energy usage data if you prefer., Name: energy_advisor
# Test ID: cost_savings_calculation_1
# Response Score: 0.44
# Tool Usage: {'used_tools': [], 'correct_tools': [], 'missing_tools': ['calculate_energy_savings'], 'extra_tools': []}
# --------------------------------------------------
# Evaluating tool usage...
# Message: Location: San Francisco, CA, Name: None
# Message: Is it cheaper to charge my EV at night or during the day?, Name: None
# Message: , Name: energy_advisor
# Message: {"date": "2025-12-30", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.117, "period": "off-peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.142, "period": "off-peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.146, "period": "off-peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.121, "period": "off-peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.147, "period": "off-peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.119, "period": "off-peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.189, "period": "peak", "demand_charge": 0.075}, {"hour": 7, "rate": 0.184, "period": "peak", "demand_charge": 0.082}, {"hour": 8, "rate": 0.224, "period": "peak", "demand_charge": 0.064}, {"hour": 9, "rate": 0.207, "period": "peak", "demand_charge": 0.071}, {"hour": 10, "rate": 0.204, "period": "peak", "demand_charge": 0.078}, {"hour": 11, "rate": 0.223, "period": "peak", "demand_charge": 0.067}, {"hour": 12, "rate": 0.216, "period": "peak", "demand_charge": 0.093}, {"hour": 13, "rate": 0.2, "period": "peak", "demand_charge": 0.085}, {"hour": 14, "rate": 0.18, "period": "peak", "demand_charge": 0.089}, {"hour": 15, "rate": 0.214, "period": "peak", "demand_charge": 0.086}, {"hour": 16, "rate": 0.204, "period": "peak", "demand_charge": 0.061}, {"hour": 17, "rate": 0.187, "period": "peak", "demand_charge": 0.08}, {"hour": 18, "rate": 0.203, "period": "peak", "demand_charge": 0.06}, {"hour": 19, "rate": 0.191, "period": "peak", "demand_charge": 0.073}, {"hour": 20, "rate": 0.195, "period": "peak", "demand_charge": 0.085}, {"hour": 21, "rate": 0.191, "period": "peak", "demand_charge": 0.054}, {"hour": 22, "rate": 0.114, "period": "off-peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.114, "period": "off-peak", "demand_charge": 0.0}]}, Name: get_electricity_prices
# Message: To determine whether it's cheaper to charge your EV at night or during the day, let's look at the electricity rates for both periods:
#
# ### Night (Off-Peak Rates)
# - **12 AM - 5 AM**: Rates range from $0.117 to $0.147 per kWh
# - **10 PM - 11 PM**: Rates are $0.114 per kWh
#
# ### Day (Peak Rates)
# - **6 AM - 10 AM**: Rates range from $0.184 to $0.224 per kWh
# - **10 AM - 6 PM**: Rates range from $0.2 to $0.223 per kWh
#
# ### Summary
# - **Night (Off-Peak)**: Average rate is approximately $0.125 per kWh.
# - **Day (Peak)**: Average rate is approximately $0.2 per kWh.
#
# ### Conclusion
# Charging your EV at night is significantly cheaper than during the day. It's advisable to take advantage of the off-peak rates to save on your electricity costs., Name: energy_advisor
# Test ID: ev_charging_2
# Response Score: 0.33
# Tool Usage: {'used_tools': ['get_electricity_prices'], 'correct_tools': ['get_electricity_prices'], 'missing_tools': [], 'extra_tools': []}
# --------------------------------------------------
# Evaluating tool usage...
# Message: Location: San Francisco, CA, Name: None
# Message: What thermostat settings should I use in winter to save energy?, Name: None
# Message: , Name: energy_advisor
# Message: {"query": "thermostat settings winter", "total_results": 5, "tips": [{"rank": 1, "content": "Saving energy at home can be simple and effective. Turn off lights when not in use and unplug devices that draw standby power. Use natural lighting during the day and replace incandescent bulbs with energy-efficient LEDs. Keep appliances clean and well-maintained to ensure they operate efficiently.\n\nSmart thermostats can save up to 10% on heating and cooling costs by automatically adjusting temperatures when you're away. Set your thermostat to 68°F in winter and 78°F in summer for optimal energy savings.\n\nWash clothes in cold water and only run full loads. Use the dryer's moisture sensor instead of timed drying. Clean the lint filter after every load to improve efficiency.\n\nSeal air leaks around windows and doors with weatherstripping or caulk. Add insulation to attics and walls to reduce heating and cooling needs.\n\nUse power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.", "source": "/Users/ahsan/Documents/Udemy/energy-advisor/ecohome-starter/data/documents/tip_energy_savings.txt", "relevance_score": "high"}, {"rank": 2, "content": "Saving energy at home can be simple and effective. Turn off lights when not in use and unplug devices that draw standby power. Use natural lighting during the day and replace incandescent bulbs with energy-efficient LEDs. Keep appliances clean and well-maintained to ensure they operate efficiently.\n\nSmart thermostats can save up to 10% on heating and cooling costs by automatically adjusting temperatures when you're away. Set your thermostat to 68°F in winter and 78°F in summer for optimal energy savings.\n\nWash clothes in cold water and only run full loads. Use the dryer's moisture sensor instead of timed drying. Clean the lint filter after every load to improve efficiency.\n\nSeal air leaks around windows and doors with weatherstripping or caulk. Add insulation to attics and walls to reduce heating and cooling needs.\n\nUse power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.", "source": "/Users/ahsan/Documents/Udemy/energy-advisor/ecohome-starter/data/documents/tip_energy_savings.txt", "relevance_score": "high"}, {"rank": 3, "content": "Use power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.\n\nConsider energy-efficient appliances when replacing old ones. Look for ENERGY STAR certified products that use 10-50% less energy than standard models.\n\nPlant trees or install awnings to provide shade for your home during summer months. This can reduce cooling costs by up to 25%.\n\nUse ceiling fans to circulate air and make rooms feel cooler, allowing you to raise the thermostat temperature by 4°F without discomfort.", "source": "/Users/ahsan/Documents/Udemy/energy-advisor/ecohome-starter/data/documents/tip_energy_savings.txt", "relevance_score": "medium"}, {"rank": 4, "content": "Use power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.\n\nConsider energy-efficient appliances when replacing old ones. Look for ENERGY STAR certified products that use 10-50% less energy than standard models.\n\nPlant trees or install awnings to provide shade for your home during summer months. This can reduce cooling costs by up to 25%.\n\nUse ceiling fans to circulate air and make rooms feel cooler, allowing you to raise the thermostat temperature by 4°F without discomfort.", "source": "/Users/ahsan/Documents/Udemy/energy-advisor/ecohome-starter/data/documents/tip_energy_savings.txt", "relevance_score": "medium"}, {"rank": 5, "content": "Dishwasher Best Practices:\n- Only run when completely full\n- Use the energy-saving or eco mode when available\n- Sched ...
# Message: To save energy during winter, consider the following thermostat settings and tips:
#
# 1. **Set Your Thermostat to 68°F**: This is the optimal temperature for energy savings during winter. Lowering the thermostat by just a few degrees can lead to significant savings.
#
# 2. **Use a Smart Thermostat**: Smart thermostats can automatically adjust temperatures when you're away, potentially saving you up to 10% on heating costs.
#
# 3. **Seal Air Leaks**: Ensure that windows and doors are properly sealed to prevent drafts. This will help maintain the desired temperature without overworking your heating system.
#
# 4. **Add Insulation**: Insulating attics and walls can reduce the need for heating, keeping your home warmer with less energy.
#
# 5. **Utilize Natural Heat**: Open curtains during sunny days to let in natural warmth and close them at night to retain heat.
#
# By implementing these strategies, you can effectively reduce your energy consumption and lower your heating bills during the winter months., Name: energy_advisor
# Test ID: thermostat_setting_2
# Response Score: 0.50
# Tool Usage: {'used_tools': ['search_energy_tips'], 'correct_tools': [], 'missing_tools': ['get_energy_saving_tips'], 'extra_tools': ['search_energy_tips']}
# --------------------------------------------------
# Evaluating tool usage...
# Message: Location: San Francisco, CA, Name: None
# Message: When is the best time to run my washing machine to save energy?, Name: None
# Message: , Name: energy_advisor
# Message: {"date": "2025-12-30", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.113, "period": "off-peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.139, "period": "off-peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.114, "period": "off-peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.146, "period": "off-peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.126, "period": "off-peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.146, "period": "off-peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.222, "period": "peak", "demand_charge": 0.056}, {"hour": 7, "rate": 0.207, "period": "peak", "demand_charge": 0.089}, {"hour": 8, "rate": 0.206, "period": "peak", "demand_charge": 0.057}, {"hour": 9, "rate": 0.198, "period": "peak", "demand_charge": 0.091}, {"hour": 10, "rate": 0.219, "period": "peak", "demand_charge": 0.07}, {"hour": 11, "rate": 0.186, "period": "peak", "demand_charge": 0.099}, {"hour": 12, "rate": 0.202, "period": "peak", "demand_charge": 0.073}, {"hour": 13, "rate": 0.185, "period": "peak", "demand_charge": 0.052}, {"hour": 14, "rate": 0.225, "period": "peak", "demand_charge": 0.083}, {"hour": 15, "rate": 0.218, "period": "peak", "demand_charge": 0.061}, {"hour": 16, "rate": 0.197, "period": "peak", "demand_charge": 0.055}, {"hour": 17, "rate": 0.215, "period": "peak", "demand_charge": 0.085}, {"hour": 18, "rate": 0.19, "period": "peak", "demand_charge": 0.056}, {"hour": 19, "rate": 0.198, "period": "peak", "demand_charge": 0.054}, {"hour": 20, "rate": 0.186, "period": "peak", "demand_charge": 0.086}, {"hour": 21, "rate": 0.224, "period": "peak", "demand_charge": 0.098}, {"hour": 22, "rate": 0.145, "period": "off-peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.15, "period": "off-peak", "demand_charge": 0.0}]}, Name: get_electricity_prices
# Message: To save energy and reduce costs when running your washing machine, it's best to operate it during off-peak hours when electricity rates are lower.
#
# Here are the off-peak hours and their corresponding rates:
#
# - **12 AM - 1 AM**: $0.113
# - **1 AM - 2 AM**: $0.139
# - **2 AM - 3 AM**: $0.114
# - **3 AM - 4 AM**: $0.146
# - **4 AM - 5 AM**: $0.126
# - **5 AM - 6 AM**: $0.146
# - **10 PM - 11 PM**: $0.145
# - **11 PM - 12 AM**: $0.150
#
# The best time to run your washing machine would be between **12 AM and 5 AM** for the lowest rates., Name: energy_advisor
# Test ID: appliance_scheduling_2
# Response Score: 0.58
# Tool Usage: {'used_tools': ['get_electricity_prices'], 'correct_tools': ['get_electricity_prices'], 'missing_tools': [], 'extra_tools': []}
# --------------------------------------------------
# Evaluating tool usage...
# Message: Location: San Francisco, CA, Name: None
# Message: What are the best practices for using solar power during cloudy days?, Name: None
# Message: , Name: energy_advisor
# Message: {"query": "solar power cloudy days", "total_results": 5, "tips": [{"rank": 1, "content": "Large devices like electric vehicles, washing machines and dishwashers often support delayed start or timer functions. Schedule these devices to run outside of peak electricity pricing hours or during periods of high solar generation. Consult your device manual for specific scheduling instructions.\n\nElectric Vehicle Charging:\n- Charge during off-peak hours (typically 11 PM to 6 AM) to save money\n- Use Level 2 charging at home for faster charging when needed\n- Set charging to complete just before you need the vehicle\n- Consider charging during peak solar generation hours if you have solar panels\n\nWashing Machine Optimization:\n- Run full loads to maximize efficiency\n- Use cold water for most loads to save energy\n- Schedule loads during off-peak hours or when solar generation is high\n- Clean the machine regularly to maintain efficiency", "source": "/Users/ahsan/Documents/Udemy/energy-advisor/ecohome-starter/data/documents/tip_device_best_practices.txt", "relevance_score": "high"}, {"rank": 2, "content": "Large devices like electric vehicles, washing machines and dishwashers often support delayed start or timer functions. Schedule these devices to run outside of peak electricity pricing hours or during periods of high solar generation. Consult your device manual for specific scheduling instructions.\n\nElectric Vehicle Charging:\n- Charge during off-peak hours (typically 11 PM to 6 AM) to save money\n- Use Level 2 charging at home for faster charging when needed\n- Set charging to complete just before you need the vehicle\n- Consider charging during peak solar generation hours if you have solar panels\n\nWashing Machine Optimization:\n- Run full loads to maximize efficiency\n- Use cold water for most loads to save energy\n- Schedule loads during off-peak hours or when solar generation is high\n- Clean the machine regularly to maintain efficiency", "source": "/Users/ahsan/Documents/Udemy/energy-advisor/ecohome-starter/data/documents/tip_device_best_practices.txt", "relevance_score": "high"}, {"rank": 3, "content": "Use power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.\n\nConsider energy-efficient appliances when replacing old ones. Look for ENERGY STAR certified products that use 10-50% less energy than standard models.\n\nPlant trees or install awnings to provide shade for your home during summer months. This can reduce cooling costs by up to 25%.\n\nUse ceiling fans to circulate air and make rooms feel cooler, allowing you to raise the thermostat temperature by 4°F without discomfort.", "source": "/Users/ahsan/Documents/Udemy/energy-advisor/ecohome-starter/data/documents/tip_energy_savings.txt", "relevance_score": "medium"}, {"rank": 4, "content": "Use power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.\n\nConsider energy-efficient appliances when replacing old ones. Look for ENERGY STAR certified products that use 10-50% less energy than standard models.\n\nPlant trees or install awnings to provide shade for your home during summer months. This can reduce cooling costs by up to 25%.\n\nUse ceiling fans to circulate air and make rooms feel cooler, allowing you to raise the thermostat temperature by 4°F without discomfort.", "source": "/Users/ahsan/Documents/Udemy/energy-advisor/ecohome-starter/data/documents/tip_energy_savings.txt", "relevance_score": "medium"}, {"rank": 5, "content": "Saving energy at home can be simple and effective. Turn off lights when not in use and unplug devices that draw standby power. Use natural lighting during the day and replace incandescent bulbs with energy-efficient LEDs. Keep appliances clean and well-maintained to ensure they operate efficiently.\n\nSmart thermostats can save up to 10% on heating and coolin ...
# Message: Here are some best practices for using solar power during cloudy days:
#
# 1. **Schedule Large Appliances**: Use the delayed start or timer functions on large devices like electric vehicles, washing machines, and dishwashers. Schedule these to run during periods of high solar generation or outside of peak electricity pricing hours.
#
#    - **Electric Vehicle Charging**:
#      - Charge during off-peak hours (typically 11 PM to 6 AM) to save money.
#      - Use Level 2 charging at home for faster charging when needed.
#      - Set charging to complete just before you need the vehicle.
#      - Consider charging during peak solar generation hours if you have solar panels.
#
#    - **Washing Machine Optimization**:
#      - Run full loads to maximize efficiency.
#      - Use cold water for most loads to save energy.
#      - Schedule loads during off-peak hours or when solar generation is high.
#      - Clean the machine regularly to maintain efficiency.
#
# 2. **Reduce Phantom Load**: Use power strips to easily turn off multiple devices at once. Many electronics continue to draw power even when turned off, known as phantom load.
#
# 3. **Consider Energy-Efficient Appliances**: When replacing old appliances, look for ENERGY STAR certified products that use 10-50% less energy than standard models.
#
# 4. **Utilize Natural Lighting**: During the day, make use of natural lighting instead of relying on electric lights.
#
# 5. **Maintain Appliances**: Keep appliances clean and well-maintained to ensure they operate efficiently. For example, clean the lint filter in your dryer after every load to improve efficiency.
#
# By implementing these practices, you can maximize your solar energy usage even on cloudy days!, Name: energy_advisor
# Test ID: solar_power_maximization_2
# Response Score: 0.62
# Tool Usage: {'used_tools': ['search_energy_tips'], 'correct_tools': [], 'missing_tools': ['get_solar_power_tips'], 'extra_tools': ['search_energy_tips']}
# --------------------------------------------------
# Evaluating tool usage...
# Message: Location: San Francisco, CA, Name: None
# Message: How much can I save by using energy-efficient appliances?, Name: None
# Message: To provide you with an accurate estimate of potential savings from using energy-efficient appliances, I need to know:
#
# 1. The type of appliance (e.g., refrigerator, washing machine, etc.).
# 2. The current energy usage of your existing appliance in kWh.
# 3. The expected energy usage of the energy-efficient appliance in kWh.
# 4. The price per kWh you are currently paying for electricity (if you know it).
#
# If you don't have the exact numbers, I can provide general estimates based on common appliances. Let me know how you'd like to proceed!, Name: energy_advisor
# Test ID: cost_savings_calculation_2
# Response Score: 0.54
# Tool Usage: {'used_tools': [], 'correct_tools': [], 'missing_tools': ['calculate_energy_savings'], 'extra_tools': []}
# --------------------------------------------------
#
# === Evaluation Summary ===
# Average Response Score: 0.52
# Total Correct Tools Used: 6
# Total Missing Tools: 7
# Total Extra Tools: 2
