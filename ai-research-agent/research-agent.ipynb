# %%
import os
from dotenv import load_dotenv
from utils.agents import Agent
from utils.llm import LLM
from utils.state_machine import Run
from utils.tools import Tool
from utils.vector_db import VectorStoreManager
from utils.rag import RAG
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 8
#       6 from utils.tools import Tool
#       7 from utils.vector_db import VectorStoreManager
# ----> 8 from utils.rag import RAG
#
# File ~/Documents/Udemy/ai-research-agent/utils/rag.py:4
#       1 from typing import TypedDict, List
#       2 import logging
# ----> 4 from utils.state_machine import StateMachine, Step, EntryPoint, Termination, Run, Resource
#       5 from utils.llm import LLM
#       6 from utils.messages import BaseMessage, UserMessage, SystemMessage
#
# ImportError: cannot import name 'Resource' from 'utils.state_machine' (/Users/ahsan/Documents/Udemy/ai-research-agent/utils/state_machine.py)

# %%
load_dotenv()

# %%
OPEN_API_KEY = os.getenv("OPENAI_API_KEY")
